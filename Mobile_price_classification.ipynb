# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set default plot style
sns.set(style="whitegrid")

# %% [markdown]
# ## Loading Datasets

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

print("Train shape:", train.shape)
print("Test shape:", test.shape)
train.head()
# Out:
# Train shape: (2000, 21)
# Test shape: (1000, 21)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# ...

# %% [markdown]
# ## Dataset Info

# %% [raw]
# Why transpose?
#
# Without transpose → statistics are rows, features are columns → harder to read if many features.
#
# With transpose → features are rows, statistics are columns → easier to compare feature-wise.
#
# Especially useful when you want to quickly scan the summary for each feature separately.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
train.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
train.shape
# Out:
# (2000, 21)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %% [markdown]
# ## Statistical Summary

# %%
train.describe().T
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %% [markdown]
# #### Numerical Summary

# %%
print("RAM:")
print("Min:", train["ram"].min())
print("Max:", train["ram"].max())
print("Mean:", train["ram"].mean())
print("Median:", train["ram"].median())
print("Std:", train["ram"].std())
print("Dtype:", train["ram"].dtype)
# Out:
# RAM:
# Min: 256
# Max: 3998
# Mean: 2124.213
# Median: 2146.5
# Std: 1084.7320436099492
# Dtype: int64

# %%
print("\nBattery Power:")
print("Min:", train["battery_power"].min())
print("Max:", train["battery_power"].max())
print("Mean:", train["battery_power"].mean())
print("Median:", train["battery_power"].median())
print("Std:", train["battery_power"].std())
print("Dtype:", train["battery_power"].dtype)
# Out:
# Battery Power:
# Min: 501
# Max: 1998
# Mean: 1238.5185
# Median: 1226.0
# Std: 439.4182060835312
# Dtype: int64

# %%
print("\nPixel Height:")
print("Min:", train["px_height"].min())
print("Max:", train["px_height"].max())
print("Mean:", train["px_height"].mean())
print("Median:", train["px_height"].median())
print("Std:", train["px_height"].std())
print("Dtype:", train["px_height"].dtype)
# Out:
# Pixel Height:
# Min: 0
# Max: 1960
# Mean: 645.108
# Median: 564.0
# Std: 443.7808108064387
# Dtype: int64

# %%
print("\nPixel Width:")
print("Min:", train["px_width"].min())
print("Max:", train["px_width"].max())
print("Mean:", train["px_width"].mean())
print("Median:", train["px_width"].median())
print("Std:", train["px_width"].std())
print("Dtype:", train["px_width"].dtype)
# Out:
# Pixel Width:
# Min: 500
# Max: 1998
# Mean: 1251.5155
# Median: 1247.0
# Std: 432.19944694633784
# Dtype: int64

# %%
print("\nMobile Weight:")
print("Min:", train["mobile_wt"].min())
print("Max:", train["mobile_wt"].max())
print("Mean:", train["mobile_wt"].mean())
print("Median:", train["mobile_wt"].median())
print("Std:", train["mobile_wt"].std())
print("Dtype:", train["mobile_wt"].dtype)
# Out:
# Mobile Weight:
# Min: 80
# Max: 200
# Mean: 140.249
# Median: 141.0
# Std: 35.399654896388334
# Dtype: int64

# %%
print("\nTalk Time:")
print("Min:", train["talk_time"].min())
print("Max:", train["talk_time"].max())
print("Mean:", train["talk_time"].mean())
print("Median:", train["talk_time"].median())
print("Std:", train["talk_time"].std())
print("Dtype:", train["talk_time"].dtype)
# Out:
# Talk Time:
# Min: 2
# Max: 20
# Mean: 11.011
# Median: 11.0
# Std: 5.463955197766686
# Dtype: int64

# %% [markdown]
# #### Categorical summary

# %%
print("Dual SIM")
print("Count:", train["dual_sim"].count())
print("Unique:", train["dual_sim"].unique())
print("Nunique:", train["dual_sim"].nunique())
print("Value Counts:\n", train["dual_sim"].value_counts())
print("Dtype:", train["dual_sim"].dtype)
# Out:
# Dual SIM
# Count: 2000
# Unique: [0 1]
# Nunique: 2
# Value Counts:
#  dual_sim
# 1    1019
# 0     981
# Name: count, dtype: int64
# Dtype: int64

# %%
print("\nBluetooth")
print("Count:", train["blue"].count())
print("Unique:", train["blue"].unique())
print("Nunique:", train["blue"].nunique())
print("Value Counts:\n", train["blue"].value_counts())
print("Dtype:", train["blue"].dtype)
# Out:
# Bluetooth
# Count: 2000
# Unique: [0 1]
# Nunique: 2
# Value Counts:
#  blue
# 0    1010
# 1     990
# Name: count, dtype: int64
# Dtype: int64

# %%
print("\n4G")
print("Count:", train["four_g"].count())
print("Unique:", train["four_g"].unique())
print("Nunique:", train["four_g"].nunique())
print("Value Counts:\n", train["four_g"].value_counts())
print("Dtype:", train["four_g"].dtype)
# Out:
# 4G
# Count: 2000
# Unique: [0 1]
# Nunique: 2
# Value Counts:
#  four_g
# 1    1043
# 0     957
# Name: count, dtype: int64
# Dtype: int64

# %%
print("\n3G")
print("Count:", train["three_g"].count())
print("Unique:", train["three_g"].unique())
print("Nunique:", train["three_g"].nunique())
print("Value Counts:\n", train["three_g"].value_counts())
print("Dtype:", train["three_g"].dtype)
# Out:
# 3G
# Count: 2000
# Unique: [0 1]
# Nunique: 2
# Value Counts:
#  three_g
# 1    1523
# 0     477
# Name: count, dtype: int64
# Dtype: int64

# %%
print("\nWi-Fi")
print("Count:", train["wifi"].count())
print("Unique:", train["wifi"].unique())
print("Nunique:", train["wifi"].nunique())
print("Value Counts:\n", train["wifi"].value_counts())
print("Dtype:", train["wifi"].dtype)
# Out:
# Wi-Fi
# Count: 2000
# Unique: [1 0]
# Nunique: 2
# Value Counts:
#  wifi
# 1    1014
# 0     986
# Name: count, dtype: int64
# Dtype: int64

# %%
print("\nTouch Screen")
print("Count:", train["touch_screen"].count())
print("Unique:", train["touch_screen"].unique())
print("Nunique:", train["touch_screen"].nunique())
print("Value Counts:\n", train["touch_screen"].value_counts())
print("Dtype:", train["touch_screen"].dtype)
# Out:
# Touch Screen
# Count: 2000
# Unique: [0 1]
# Nunique: 2
# Value Counts:
#  touch_screen
# 1    1006
# 0     994
# Name: count, dtype: int64
# Dtype: int64

# %% [markdown]
# ## Missing Values & Duplicates

# %%
print("Missing Values:\n", train.isnull().sum())
print("\nDuplicate Rows:", train.duplicated().sum())
# Out:
# Missing Values:
#  battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64
#
# Duplicate Rows: 0

# %% [markdown]
# ## Target Variable Distribution

# %%
sns.countplot(
    x="price_range", 
    data=train, 
    hue="price_range", 
    palette="Set2", 
    legend=False
)
plt.title("Distribution of Price Range")
plt.show()

# %% [markdown]
# ### Univariate Analysis – Example Battery Power

# %%
sns.histplot(train['battery_power'], bins=30)
plt.title("Battery Power Distribution")
plt.show()

# %% [markdown]
# ## Univariate Analysis: RAM

# %%
sns.histplot(train['ram'], bins=30)
plt.title("RAM Distribution")
plt.show()

# %% [markdown]
# ## Univariate Categorical

# %% [markdown]
# #### Bluetooth

# %%
# 🏷️ Univariate Analysis - Bluetooth
sns.countplot(x='blue', data=train, color="red")
plt.title("Bluetooth Distribution")
plt.show()

# %% [markdown]
# ### WI-FI

# %%
# 🏷️ Univariate Analysis - Wi-Fi
sns.countplot(x='wifi', data=train, color="violet")
plt.title("Wi-Fi Distribution")
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical vs Numerical

# %% [markdown]
# #### RAM vs Battery Power

# %%
# 🔗 Bivariate Analysis - RAM vs Battery Power
sns.scatterplot(x="ram", y="battery_power", data=train, color="blue", alpha=0.6)
plt.title("RAM vs Battery Power")
plt.show()

# %% [markdown]
# #### Pixel Width vs Pixel Height

# %%
# 🔗 Bivariate Analysis - Pixel Width vs Pixel Height
sns.scatterplot(x="px_width", y="px_height", data=train, color="purple", alpha=0.6)
plt.title("Pixel Width vs Pixel Height")
plt.show()

# %% [markdown]
# ### Mobile Weight vs Battery Power

# %%
# 🔗 Bivariate Analysis - Mobile Weight vs Battery Power
sns.scatterplot(x="mobile_wt", y="battery_power", data=train, color="orange", alpha=0.6)
plt.title("Mobile Weight vs Battery Power")
plt.show()

# %% [markdown]
# ### Numerical vs Categorical

# %% [markdown]
# #### RAM vs Price Range

# %%
# 🔗 Bivariate Analysis - RAM vs Price Range
sns.boxplot(x="price_range", y="ram", data=train, palette="coolwarm", hue="price_range", legend=False)
plt.title("RAM vs Price Range")
plt.show()

# %% [markdown]
# #### Battery Power vs Price Range

# %%
# 🔗 Bivariate Analysis - Battery Power vs Price Range
sns.boxplot(x="price_range", y="battery_power", data=train, palette="viridis", hue="price_range", legend=False)
plt.title("Battery Power vs Price Range")
plt.show()

# %% [markdown]
# ## Talk Time vs Price Range

# %%
# 🔗 Bivariate Analysis - Talk Time vs Price Range
sns.boxplot(x="price_range", y="talk_time", data=train, palette="cividis", hue="price_range", legend=False)
plt.title("Talk Time vs Price Range")
plt.show()

# %% [markdown]
# ## Categorical vs Categorical

# %%
# 🔗 Bivariate Analysis - Dual SIM vs Bluetooth
sns.countplot(x="dual_sim", data=train, hue="blue", palette="pastel")
plt.title("Dual SIM vs Bluetooth")
plt.show()

# %% [markdown]
# ### 3G VS 4G

# %%
# 🔗 Bivariate Analysis - 3G vs 4G
sns.countplot(x="three_g", data=train, hue="four_g", palette="Set2")
plt.title("3G vs 4G")
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(12,8))
sns.heatmap(train.corr(), cmap="coolwarm", annot=False)
plt.title("Correlation Heatmap of Features")
plt.show()

# %% [markdown]
# ## Feature vs Target Mapping

# %%
feature_map = {
    "battery_power": {"title": "Battery Power vs Price Range", "palette": "viridis"},
    "ram": {"title": "RAM vs Price Range", "palette": "coolwarm"},
    "int_memory": {"title": "Internal Memory vs Price Range", "palette": "magma"},
    "mobile_wt": {"title": "Mobile Weight vs Price Range", "palette": "Spectral"},
    "px_width": {"title": "Pixel Resolution Width vs Price Range", "palette": "plasma"},
    "px_height": {"title": "Pixel Resolution Height vs Price Range", "palette": "cividis"},
    "talk_time": {"title": "Talk Time vs Price Range", "palette": "Set2"},
    "sc_w": {"title": "Screen Width vs Price Range", "palette": "cubehelix"},
    "sc_h": {"title": "Screen Height vs Price Range", "palette": "rocket"},
    "n_cores": {"title": "Number of Cores vs Price Range", "palette": "YlOrBr"},
    "fc": {"title": "Front Camera MP vs Price Range", "palette": "Blues"},
    "pc": {"title": "Primary Camera MP vs Price Range", "palette": "Greens"}
}

# %% [markdown]
# ## Battery Power vs Price Range

# %%
sns.boxplot(
    x="price_range", 
    y="battery_power", 
    data=train, 
    hue="price_range",       # fix: add hue
    palette="coolwarm", 
    legend=False             # avoid duplicate legend
)
plt.title("Battery Power vs Price Range")
plt.show()

# %% [markdown]
# ## RAM vs Price Range

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    x="price_range",
    y="ram",
    data=train,
    hue="price_range",                         # ✅ add hue
    palette=feature_map["ram"]["palette"], 
    legend=False                               # ✅ suppress duplicate legend
)
plt.title(feature_map["ram"]["title"])
plt.show()

# %% [markdown]
# ## Internal Memory vs Price Range

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    x="price_range",
    y="int_memory",
    data=train,
    hue="price_range",                           # ✅ fix: add hue
    palette=feature_map["int_memory"]["palette"],
    legend=False                                 # ✅ no duplicate legend
)
plt.title(feature_map["int_memory"]["title"])
plt.show()

# %% [markdown]
# ## Mobile Weight vs Price Range

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    x="price_range",
    y="mobile_wt",
    data=train,
    hue="price_range",                           # ✅ fix: add hue
    palette="coolwarm",                          # you can replace with your feature_map if defined
    legend=False                                 # ✅ avoid duplicate legend
)
plt.title("Mobile Weight vs Price Range")
plt.xlabel("Price Range (0 = Low, 1 = Medium, 2 = High, 3 = Very High)")
plt.ylabel("Mobile Weight (grams)")
plt.show()

# %% [markdown]
# ## Pixel Resolution Height vs Price Range

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    x="price_range",
    y="px_height",
    data=train,
    hue="price_range",                           # ✅ fix: add hue
    palette=feature_map["px_height"]["palette"],
    legend=False                                 # ✅ avoid duplicate legend
)
plt.title(feature_map["px_height"]["title"])
plt.xlabel("Price Range (0 = Low, 1 = Medium, 2 = High, 3 = Very High)")
plt.ylabel("Pixel Height")
plt.show()

# %% [markdown]
# ## Talk Time vs Price Range

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    x="price_range",
    y="talk_time",
    data=train,
    hue="price_range",                           # ✅ fix: add hue
    palette=feature_map["talk_time"]["palette"],
    legend=False                                 # ✅ avoid duplicate legend
)
plt.title(feature_map["talk_time"]["title"])
plt.xlabel("Price Range (0 = Low, 1 = Medium, 2 = High, 3 = Very High)")
plt.ylabel("Talk Time (hours)")
plt.show()
